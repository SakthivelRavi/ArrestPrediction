# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crime = pd.read_csv("data.csv")

# %%
plt.xticks(rotation=90)
sns.countplot(x='Primary Type', hue='Arrest', data=crime)
plt.show()

# %%
arrest_rates = crime[['Primary Type', 'Arrest']].groupby('Primary Type', as_index=False).mean()

# %%
sns.barplot(x='Primary Type', y='Arrest', data=arrest_rates)
plt.xticks(rotation=90)
plt.show()
